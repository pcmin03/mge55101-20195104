# %% [markdown]
# # Skeleton code for CIFAR datasets
# - use the code for the implementation of CIFAR dataloaders

# %%
# !nvidia-smi
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import torch.nn.functional as F
print(torch.__version__)
# Out:
# Thu Apr 30 06:23:45 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.33.01    Driver Version: 440.33.01    CUDA Version: 10.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 108...  Off  | 00000000:04:00.0 Off |                  N/A |
# | 23%   29C    P8     7W / 250W |   1187MiB / 11178MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce GTX 108...  Off  | 00000000:06:00.0 Off |                  N/A |
# | 23%   25C    P8     8W / 250W |     10MiB / 11178MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   2  GeForce GTX 108...  Off  | 00000000:07:00.0 Off |                  N/A |
# | 47%   78C    P2   215W / 250W |  10531MiB / 11178MiB |     62%      Default |
# +-------------------------------+----------------------+----------------------+
# |   3  GeForce GTX 108...  Off  | 00000000:08:00.0 Off |                  N/A |
# | 23%   30C    P8     8W / 250W |     10MiB / 11178MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   4  GeForce GTX 108...  Off  | 00000000:0C:00.0 Off |                  N/A |
# | 23%   30C    P8     8W / 250W |   2106MiB / 11178MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   5  GeForce GTX 108...  Off  | 00000000:0D:00.0 Off |                  N/A |
# | 23%   32C    P8     8W / 250W |     10MiB / 11178MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   6  GeForce GTX 108...  Off  | 00000000:0E:00.0 Off |                  N/A |
# | 36%   62C    P2   122W / 250W |  10763MiB / 11178MiB |     52%      Default |
# +-------------------------------+----------------------+----------------------+
# |   7  GeForce GTX 108...  Off  | 00000000:0F:00.0 Off |                  N/A |
# | 23%   33C    P8     8W / 250W |     10MiB / 11178MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+
# 1.2.0

# %% [markdown]
# # Model
#
# - write your LeNet and AlexNet code in the following ```LeNet,AlexNet``` class

# %%
class LeNet(nn.Module):
    
    def __init__(self,in_channel,out_channel):
        super(LeNet,self).__init__()

        self.convs = nn.ModuleList([nn.Conv2d(in_channel,6,5,padding=2),nn.Conv2d(6,16,5)])
        
        self.linears = nn.ModuleList([nn.Linear(16*6*6,120),nn.Linear(120,84)])
        self.final_linear = nn.Linear(84,out_channel)
    def forward(self,x):
        # convolution layers 
        for conv in self.convs:
            x = conv(x)
            x = F.sigmoid(x)
            x = F.avg_pool2d(x,2,2)
        #Flatten
        x = x.view(x.size(0),-1)
        # Linears layers
        for linear in self.linears:
            x = linear(x)
            x = F.sigmoid(x)
        x = self.final_linear(x)
        return x

class AlexNet(nn.Module):

    def __init__(self,in_channel,out_channel):
        super(AlexNet,self).__init__()
        
        self.convs = nn.ModuleList([nn.Conv2d(in_channel,64,3,2,padding=1),nn.Conv2d(64,192,3,padding=1),
                                    nn.Conv2d(192,384,3,padding=1),nn.Conv2d(384,256,3,padding=1),
                                    nn.Conv2d(256,256,3,padding=1)])
        self.linears = nn.ModuleList([nn.Linear(256*2*2,4096),nn.Linear(4096,4096)])
        self.final_linear = nn.Linear(4096,out_channel)
        
    def forward(self,x):
        #convolution layers
        for i, conv in enumerate(self.convs):
            if i < 2:
                x = conv(x)
                x = F.relu(x)
                x = F.max_pool2d(x,2)
            else:
                x = conv(x)
                x = F.relu(x)
        x = F.max_pool2d(x,2)
        #Flatten
        x = x.view(x.size(0),-1)
        # Linears layers
        for linear in self.linears:
            x = F.dropout(x)
            x = linear(x)
            x = F.relu(x)

        x = self.final_linear(x)
        return x
    
# device = torch.device('cuda:3'if torch.cuda.is_available() else "else")
# you can change model(example : Alexnet, LeNet)
model = LeNet(3,10).cuda()

#Loss function & optimizers
"""
you can change the loss and optimizer
"""
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)


# Hyperparameters
"""
you can change the value
"""
num_epochs = 300
batch_size = 128

# %% [markdown]
# # Training & Evalutaion
# - Don't change the below codes

# %%
import sys
sys.path.insert(0, "..")
from torch.utils.data import DataLoader
import torchvision
import torchvision.transforms as transforms

# CIFAR preprocessing 
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

# DataLoader for CIFAR-10
cifar_train = torchvision.datasets.CIFAR10(root="./", 
                                         train=True, 
                                         download=True,
                                         transform=transform_train
                                         )
cifar_test = torchvision.datasets.CIFAR10(root="./", 
                                        train=False, 
                                        download=True,
                                        transform=transform_test)


train_loader = DataLoader(cifar_train, batch_size=batch_size, shuffle=True, num_workers=4)
test_loader = DataLoader(cifar_test, batch_size=batch_size, shuffle=False, num_workers=4)

 
accuracy_graph = {'train':[], 'test':[], 'epoch': []}
loss_graph = {'train':[], 'test':[], 'epoch': []}

class accumulator():
    def __init__(self):
        self.cnt = 0
        self.obs = 0
        self.loss = 0

    def add(self, predict, output):

        assert len(predict) == len(output)

        self.cnt += self.count(predict, output).cpu().numpy()
        self.obs += len(predict)
    
    def count(self, predict, output):
        correct = torch.sum(torch.argmax(predict, dim=1) == output)
        
        return correct
        
    def loss_update(self, loss, batch_size):
        self.loss += loss * batch_size

    def running_stat(self):
        if self.obs != 0:
            run_acc = 100 * self.cnt / self.obs
            run_loss = self.loss / self.obs
        else: 
            run_acc = 0
            rum_loss = 0

        return run_acc, run_loss

    def reset(self):
        self.__init__()


for epoch in range(num_epochs):

    train_accuracy = accumulator()
    test_accuracy = accumulator()

    # Training
    for train_x, train_y in train_loader: 

        train_x, train_y = train_x.cuda(), train_y.cuda()
        train_predict = model(train_x)
        loss = criterion(train_predict, train_y)

        # Backpropagation        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_accuracy.add(train_predict, train_y)
        train_accuracy.loss_update(loss, batch_size)

    # Evaluation
    if epoch % 10 ==0:
             
        for test_x, test_y in test_loader:

            with torch.autograd.no_grad():
                test_x, test_y = test_x.cuda(), test_y.cuda()
                test_predict = model(test_x)
                test_accuracy.add(test_predict, test_y)

            loss_test = criterion(test_predict, test_y)
            test_accuracy.loss_update(loss_test, batch_size)

        train_acc, train_loss = train_accuracy.running_stat()
        test_acc, test_loss = test_accuracy.running_stat()
        accuracy_graph['train'].append(train_acc)
        accuracy_graph['test'].append(test_acc) 
        accuracy_graph['epoch'].append(epoch)
        loss_graph['train'].append(train_loss)
        loss_graph['test'].append(test_loss)
        loss_graph['epoch'].append(epoch)
        
        print("\ntrain accuracy: {:.2f} %, test accuracy: {:.2f} %".format(train_acc, test_acc))
        print("epoch:{}, train_loss: {:.4f}, test_loss: {:.4f}".format(epoch+1, train_loss, test_loss)) 

        train_accuracy.reset(), test_accuracy.reset()


plt.plot(accuracy_graph['epoch'], accuracy_graph['train'], label = "train accuracy");
plt.plot(accuracy_graph['epoch'], accuracy_graph['test'], label = "test_accuracy");
plt.legend()
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.show()

plot_loss_train = plt.plot(loss_graph['epoch'], loss_graph['train'], label="train loss");
plt.plot(loss_graph['epoch'], loss_graph['test'], label="test loss");
plt.legend()
plt.xlabel("epoch")
plt.ylabel("loss")
plt.show()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# /opt/conda/lib/python3.6/site-packages/torch/nn/functional.py:1350: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# train accuracy: 19.88 %, test accuracy: 28.51 %
# epoch:1, train_loss: 2.1126, test_loss: 1.9725
#
# train accuracy: 45.58 %, test accuracy: 48.83 %
# epoch:11, train_loss: 1.4901, test_loss: 1.4103
#
# train accuracy: 49.69 %, test accuracy: 52.52 %
# epoch:21, train_loss: 1.3820, test_loss: 1.3295
#
# train accuracy: 52.55 %, test accuracy: 54.01 %
# epoch:31, train_loss: 1.3136, test_loss: 1.2917
#
# train accuracy: 54.60 %, test accuracy: 57.47 %
# epoch:41, train_loss: 1.2595, test_loss: 1.1912
#
# train accuracy: 56.31 %, test accuracy: 57.44 %
# epoch:51, train_loss: 1.2165, test_loss: 1.1929
#
# train accuracy: 58.02 %, test accuracy: 59.57 %
# epoch:61, train_loss: 1.1707, test_loss: 1.1301
#
# train accuracy: 58.86 %, test accuracy: 61.19 %
# epoch:71, train_loss: 1.1488, test_loss: 1.0920
#
# train accuracy: 60.20 %, test accuracy: 61.14 %
# epoch:81, train_loss: 1.1151, test_loss: 1.1072
#
# train accuracy: 61.44 %, test accuracy: 63.50 %
# epoch:91, train_loss: 1.0863, test_loss: 1.0335
#
# train accuracy: 62.06 %, test accuracy: 63.06 %
# epoch:101, train_loss: 1.0628, test_loss: 1.0357
#
# train accuracy: 63.06 %, test accuracy: 63.88 %
# epoch:111, train_loss: 1.0431, test_loss: 1.0229
#
# train accuracy: 63.80 %, test accuracy: 64.43 %
# epoch:121, train_loss: 1.0206, test_loss: 1.0132
#
# train accuracy: 64.22 %, test accuracy: 65.07 %
# epoch:131, train_loss: 1.0069, test_loss: 0.9923
#
# train accuracy: 64.68 %, test accuracy: 65.46 %
# epoch:141, train_loss: 0.9897, test_loss: 0.9709
#
# train accuracy: 65.26 %, test accuracy: 66.13 %
# epoch:151, train_loss: 0.9736, test_loss: 0.9551
#
# train accuracy: 65.77 %, test accuracy: 67.47 %
# epoch:161, train_loss: 0.9651, test_loss: 0.9392
#
# train accuracy: 65.95 %, test accuracy: 67.10 %
# epoch:171, train_loss: 0.9565, test_loss: 0.9411
#
# train accuracy: 66.47 %, test accuracy: 67.65 %
# epoch:181, train_loss: 0.9470, test_loss: 0.9393
#
# train accuracy: 66.60 %, test accuracy: 67.91 %
# epoch:191, train_loss: 0.9414, test_loss: 0.9129
#
# train accuracy: 66.89 %, test accuracy: 67.51 %
# epoch:201, train_loss: 0.9308, test_loss: 0.9288
#
# train accuracy: 67.35 %, test accuracy: 68.38 %
# epoch:211, train_loss: 0.9275, test_loss: 0.9155
#
# train accuracy: 67.35 %, test accuracy: 69.23 %
# epoch:221, train_loss: 0.9207, test_loss: 0.8920
#
# train accuracy: 67.51 %, test accuracy: 68.19 %
# epoch:231, train_loss: 0.9156, test_loss: 0.9182
#
# train accuracy: 68.08 %, test accuracy: 68.92 %
# epoch:241, train_loss: 0.9052, test_loss: 0.8980
#
# train accuracy: 68.01 %, test accuracy: 69.20 %
# epoch:251, train_loss: 0.9012, test_loss: 0.8929
#
# train accuracy: 67.82 %, test accuracy: 68.94 %
# epoch:261, train_loss: 0.9041, test_loss: 0.9001
#
# train accuracy: 68.34 %, test accuracy: 68.73 %
# epoch:271, train_loss: 0.8916, test_loss: 0.8980
#
# train accuracy: 68.36 %, test accuracy: 68.78 %
# epoch:281, train_loss: 0.8906, test_loss: 0.8931
#
# train accuracy: 68.89 %, test accuracy: 69.65 %
# epoch:291, train_loss: 0.8820, test_loss: 0.8791
